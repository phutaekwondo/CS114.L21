# %% [markdown]
# <a href="https://colab.research.google.com/github/phutaekwondo/CS114.L21/blob/main/Final_project/detection_helmet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DEMO Đồ án môn học Máy Học

# %% [markdown]
# # Giới thiệu nhóm:
# 1. 19522020-Lại Nguyễn Vĩnh Phú
# 2. 19522020-Nguyễn Chí Cường
# 3. 19522447-Trương Thế Trương

# %% [markdown]
# # **1. Đề tài**

# %% [markdown]
# ## 1.1. Giới thiệu

# %% [markdown]
# Hiện nay có ra nhiều vụ tai nạn chết người, chiếm phần lớn là những người tham gia giao thông với xe hai bánh. Và chiếm không ítlà những người đi xe không mang mũ bảo hiểm.
#
# Hiện nay, việc quan sát các phương tiện giao thông hiện đang rất phổ biến để cho mọi người tham gia giao thông tuân thủ và chấp hành. Và cũng như bắt giữ những vi phạm giao thông nói chung và những người tham gia giao thông xe hai bánh không đội mũ bảo hiểm nói riêng.

# %% [markdown]
# ![phatnguoi-15940590442311750170070.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Những khi các cơ quan chức năng xem lại thời gian rất tốn thời gian.
#
# Thế nên việc tích hợp Machine learning vào luôn máy tính kết nói camera để quan sát những người không đội mũ bảo hiểm vào thêm vào hệ thống.

# %% [markdown]
# ## 1.2. Ứng dụng

# %% [markdown]
# Camera quan sát đối tượng không mang mũ bảo hiểm thì cho vào danh sách chẳng hạn thời gian phát hiện, biển số xe(nếu phát hiện).

# %% [markdown]
# > Hoạt động
#
# Máy tính sẽ nhận diện:
#   - Xe máy, xe hai bánh:
#
#     + Nếu đối tượng không mang mũ bảo hiểm thì thêm vào danh sách vi phạm
#
#     + Nếu đối tượng mang mũ thì thôi.
#
#   - Xe bốn bánh, container, ... thì bỏ qua vì mô hình chỉ nhận diện những đối tượng vi phạm không đội mũ bảo hiểm khi đi xe gắn máy, xe hai bánh.

# %% [markdown]
# > Nhận diện những đối tượng không đội mũ bảo hiểm

# %% [markdown]
# ![hellmet.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Phát hiện đối tượng vi phạm không đội vũ đưa vào database, và thời gian vi phạm, ...
#
# Sau đó giải quyết.

# %% [markdown]
# # **2. Mô tả bài toán.**

# %% [markdown]
# > Input: Ảnh từ camera giám sát
#
# > Output: Đối tượng vi phạm

# %% [markdown]
# # Dự liệu
#
# > Thu thập bằng cách tự chụp, và tìm kiếm trong internet
#
# > Số lượng dự tính 5000 ảnh, hoặc hơn nếu có thể
